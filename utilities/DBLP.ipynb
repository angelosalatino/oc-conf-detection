# %% [markdown]
# # SPARQL Query
#
#
#
# ```
# PREFIX rdf: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dblp: <https://dblp.org/rdf/schema#>
# SELECT *
# WHERE{
# ?s ?p <https://dblp.org/rdf/schema#Conference> .
# ?s rdf:label ?label .
# ?s dblp:primaryStreamTitle ?label2 .
# ?s dblp:streamTitle ?label3 .
# }
# ```
#
# Eventually, I downloaded the file from [https://sparql.dblp.org/1RSnO4#csv](https://sparql.dblp.org/1RSnO4#csv)

# %%
import pandas as pd
import re

# %%
df = pd.read_csv("1RSnO4.csv")

# %%
ids_confs = {}
unique_confs = {}
for ix, row in df.iterrows():
    conf_id = row["s"].replace("https://dblp.org/streams/conf/","")
    ids_confs[conf_id] = row["label"]
    
    unique_confs[row["label"]] = conf_id
    unique_confs[row["label2"]] = conf_id
    unique_confs[row["label3"]] = conf_id
    cleaned_name = re.sub(r'\([^)]*\)', '', row["label"]).strip()
    if cleaned_name not in unique_confs:
        unique_confs[cleaned_name] = conf_id
    cleaned_name = re.sub(r'\([^)]*\)', '', row["label2"]).strip()
    if cleaned_name not in unique_confs:
        unique_confs[cleaned_name] = conf_id
    cleaned_name = re.sub(r'\([^)]*\)', '', row["label3"]).strip()
    if cleaned_name not in unique_confs:
        unique_confs[cleaned_name] = conf_id

# %%
unique_confs
# Out:
# {'International Workshop on Collaborative Virtual Environments (3DCVE)': '3dcve-ws',
#  'International Workshop on Collaborative Virtual Environments': '3dcve-ws',
#  'International Workshop on 3D Geoinformation Systems (3D-GIS)': '3dgis',
#  'International Workshop on 3D Geoinformation Systems': '3dgis',
#  'IEEE International Conference on 3D System Integration (3DIC)': '3dic',
#  'IEEE International Conference on 3D System Integration': '3dic',
#  '3D Imaging and Applications (3DIA)': '3dica',
#  '3D Imaging and Applications': '3dica',
#  'International Conference on 3D Vision (3DV)': '3dim',
#  'International Conference on 3D Vision': '3dim',
#  'Eurographics Workshop on 3D Object Retrieval (3DOR)': '3dor',
#  'Eurographics Workshop on 3D Object Retrieval': '3dor',
#  '3D Physiological Human Workshop (3DPH)': '3dph',
#  '3D Physiological Human Workshop': '3dph',
#  '3D Data Processing Visualization and Transmission (3DPVT)': '3dpvt',
#  '3D Data Processing Visualization and Transmission': '3dpvt',
#  '3DTV-Conference (3DTV)': '3dtv',
#  '3DTV-Conference': '3dtv',
#  'IEEE Symposium on 3D User Interfaces (3DUI)': '3dui',
#  'IEEE Symposium on 3D User Interfaces': '3dui',
#  'International Workshop on Professional Retraining and Life-Long Learning using ICT: Person-oriented Approach (3L-Person)': '3lperson',
#  'International Workshop on Professional Retraining and Life-Long Learning using ICT: Person-oriented Approach': '3lperson',
#  'International Conference on P2P, Parallel, Grid, Cloud and Internet Computing (3PGCIC)': '3pgcic',
#  'International Conference on P2P, Parallel, Grid, Cloud and Internet Computing': '3pgcic',
#  'Workshop on 5G and Beyond Network Measurements, Modeling, and Use Cases (5G-MeMU)': '5g-memu',
#  'Workshop on 5G and Beyond Network Measurements, Modeling, and Use Cases': '5g-memu',
#  'International Conference on 5G for Ubiquitous Connectivity (5GU)': '5gu',
#  'International Conference on 5G for Ubiquitous Connectivity': '5gu',
#  '5G World Forum (5GWF)': '5gwf',
#  '5G World Forum': '5gwf',
#  'International Conference on 6GN for Future Wireless Networks (6GN)': '5gwn',
#  'International Conference on 6GN for Future Wireless Networks': '5gwn',
#  'International Conference on 6G Networking (6GNet)': '6gnet',
#  'International Conference on 6G Networking': '6gnet',
#  '6G Wireless Summit (6G SUMMIT)': '6gsummit',
#  '6G Wireless Summit': '6gsummit',
#  'Amrita ACM-W Celebration on Women in Computing in India (A2CWiC)': 'a2cwic',
#  'Amrita ACM-W Celebration on Women in Computing in India': 'a2cwic',
#  'Summer School on Accountability and Security in the Cloud (A4Cloud)': 'a4cloud',
#  'Summer School on Accountability and Security in the Cloud': 'a4cloud',
#  'Advanced Architectures and Algorithms for Internet Delivery and Applications (AAA-IDEA)': 'aaa-idea',
#  'Advanced Architectures and Algorithms for Internet Delivery and Applications': 'aaa-idea',
#  'AAAI Conference on Artificial Intelligence (AAAI)': 'aaai',
#  'AAAI Conference on Artificial Intelligence': 'aaai',
#  'AAAI Fall Symposium Series': 'aaaifs',
#  'AAAI Spring Symposia': 'aaaiss',
#  'European Conference on the Advancement of Assistive Technology (AAATE)': 'aaate',
#  'European Conference on the Advancement of Assistive Technology': 'aaate',
#  'Symposium on Advances in Approximate Bayesian Inference (AABI)': 'aabi',
#  'Symposium on Advances in Approximate Bayesian Inference': 'aabi',
#  'Asian Applied Computing Conference (AACC)': 'aacc',
#  'Asian Applied Computing Conference': 'aacc',
#  'Conference of the Asia-Pacific Chapter of the Association for Computational Linguistics (AACL)': 'aacl',
#  'Conference of the Asia-Pacific Chapter of the Association for Computational Linguistics': 'aacl',
#  'Automated and Algorithmic Debugging (AADEBUG)': 'aadebug',
#  'Automated and Algorithmic Debugging': 'aadebug',
#  'Algebraic and Algorithmic Aspects of Differential and Integral Operators (AADIOS)': 'aadios',
#  'Algebraic and Algorithmic Aspects of Differential and Integral Operators': 'aadios',
#  'International Symposium on Applied Algebra, Algebraic Algorithms and Error-Correcting Codes (AAECC)': 'aaecc',
#  'International Symposium on Applied Algebra, Algebraic Algorithms and Error-Correcting Codes': 'aaecc',
#  'Apprentissage Artificiel et Fouille de Données (AAFD)': 'aafd',
#  'Apprentissage Artificiel et Fouille de Données': 'aafd',
#  'Advances in Architectural Geometry (AAG)': 'aag',
#  'Advances in Architectural Geometry': 'aag',
#  'Workshop on Automated Assessment and Guidance of Project Work (AAGPW)': 'aagpw',
#  'Workshop on Automated Assessment and Guidance of Project Work': 'aagpw',
#  'International Conference on Advances in Artificial Intelligence and Applications (AAIA)': 'aaia',
#  'International Conference on Advances in Artificial Intelligence and Applications': 'aaia',
#  'Algorithmic Aspects in Information and Management (AAIM)': 'aaim',
#  'Algorithmic Aspects in Information and Management': 'aaim',
#  'International Workshop on Approaches and Applications of Inductive Programming (AAIP)': 'aaip',
#  'International Workshop on Approaches and Applications of Inductive Programming': 'aaip',
#  'Workshop on Advanced Analytics and Learning on Temporal Data (AALTD)': 'aaltd',
#  'Workshop on Advanced Analytics and Learning on Temporal Data': 'aaltd',
#  'European Symposium on Adaptive and Learning Agents and Multi-Agent Systems (ALAMAS)': 'aamas',
#  'European Symposium on Adaptive and Learning Agents and Multi-Agent Systems': 'aamas',
#  'Conference on Algorithmic Algebra and Number Theory': 'aant',
#  'Workshop on Adjustable Autonomy and Physical Embodied Intelligence (AAPEI)': 'aapei',
#  'Workshop on Adjustable Autonomy and Physical Embodied Intelligence': 'aapei',
#  'Decennial Aarhus Conference on Critical Alternatives': 'aarhus',
#  'Algebraic Biology (AB)': 'ab',
#  'Algebraic Biology': 'ab',
#  'International Conference on Activity and Behavior Computing (ABC)': 'abc',
#  'International Conference on Activity and Behavior Computing': 'abc',
#  'Anticipatory Behavior in Adaptive Learning Systems (ABiALS)': 'abials',
#  'Anticipatory Behavior in Adaptive Learning Systems': 'abials',
#  'International Workshop on Advances in Business ICT (ABICT)': 'abict',
#  'International Workshop on Advances in Business ICT': 'abict',
#  'International Workshop on Aspect-Based and Model-Based Separation of Concerns in Software Systems (ABMB)': 'abmb',
#  'International Workshop on Aspect-Based and Model-Based Separation of Concerns in Software Systems': 'abmb',
#  'Workshop Automatische Bewertung von Programmieraufgaben (ABP)': 'abp',
#  'Workshop Automatische Bewertung von Programmieraufgaben': 'abp',
#  'Advanced Courses (AC)': 'ac',
#  'Advanced Courses': 'ac',
#  'Conference on Advanced Computer Architecture (ACA)': 'aca',
#  'Conference on Advanced Computer Architecture': 'aca',
#  'International Conference on Advances in Computing and Artificial Intelligence (ACAI)': 'acai',
#  'International Conference on Advances in Computing and Artificial Intelligence': 'acai',
#  'International Conference on Algorithms, Computing and Artificial Intelligence (ACAI)': 'acai2',
#  'International Conference on Algorithms, Computing and Artificial Intelligence': 'acai2',
#  'European Advanced Course on AI (ACAI)': 'acai3',
#  'European Advanced Course on AI': 'acai3',
#  'Australian Conference on Artificial Life (ACAL)': 'acal',
#  'Australian Conference on Artificial Life': 'acal',
#  'Australasian Conference on Artificial Life and Computational Intelligence (ACALCI)': 'acalci',
#  'Australasian Conference on Artificial Life and Computational Intelligence': 'acalci',
#  'International Workshop on Agent-based Complex Automated Negotiations (ACAN)': 'acan',
#  'International Workshop on Agent-based Complex Automated Negotiations': 'acan',
#  'International Workshop on Advances in Civil Aviation Systems Development (ACASD)': 'acasd',
#  'International Workshop on Advances in Civil Aviation Systems Development': 'acasd',
#  'Advances in Computing and Communications (ACC)': 'acc',
#  'Advances in Computing and Communications': 'acc',
#  'Asian Conference on Computer Aided Surgery (ACCAS)': 'accas',
#  'Asian Conference on Computer Aided Surgery': 'accas',
#  'Workshop on Applied and Computational Category Theory (ACCAT)': 'accat',
#  'Workshop on Applied and Computational Category Theory': 'accat',
#  'Asia Conference on Computers and Communications  (ACCC)': 'accc',
#  'Asia Conference on Computers and Communications': 'accc',
#  'International Conference on Access Networks (AccessNets)': 'accessnets',
#  'International Conference on Access Networks': 'accessnets',
#  'International Workshop on Algebraic and Combinatorial Coding Theory (ACCT)': 'acct',
#  'International Workshop on Algebraic and Combinatorial Coding Theory': 'acct',
#  'Accurate Scientific Computations': 'accurate',
#  'Asian Conference on Computer Vision (ACCV)': 'accv',
#  'Asian Conference on Computer Vision': 'accv',
#  'SIAM Conference on Applied and Computational Discrete Algorithms (ACDA)': 'acda',
#  'SIAM Conference on Applied and Computational Discrete Algorithms': 'acda',
#  'Workshop on Automated Control for Datacenters and Clouds (ACDC)': 'acdc',
#  'Workshop on Automated Control for Datacenters and Clouds': 'acdc',
#  'Australasian Computing Education Conference (ACE)': 'ace',
#  'Australasian Computing Education Conference': 'ace',
#  'International Conference on Advances in Cybersecurity (ACeS)': 'aces',
#  'International Conference on Advances in Cybersecurity': 'aces',
#  'Annual Conference of Fuzzy Information and Engineering (ACFIE)': 'acfie',
#  'Annual Conference of Fuzzy Information and Engineering': 'acfie',
#  'Advances in Computer Games (ACG)': 'acg',
#  'Advances in Computer Games': 'acg',
#  'International Conference on Advances in Computer-Human Interaction (ACHI)': 'achi',
#  'International Conference on Advances in Computer-Human Interaction': 'achi',
#  'Algorithms and Complexity in Durham (ACiD)': 'acid',
#  'Algorithms and Complexity in Durham': 'acid',
#  'Affective Computing and Intelligent Interaction (ACII)': 'acii',
#  'Affective Computing and Intelligent Interaction': 'acii',
#  'Asian Conference on Intelligent Information and Database Systems (ACIIDS)': 'aciids',
#  'Asian Conference on Intelligent Information and Database Systems': 'aciids',
#  'Advances in Computational Intelligence and Learning (ACIL)': 'acil',
#  'Advances in Computational Intelligence and Learning': 'acil',
#  'Asia-Pacific Conference on Intelligent Robot Systems (ACIRS)': 'acirs',
#  'Asia-Pacific Conference on Intelligent Robot Systems': 'acirs',
#  'Australasian Conference on Information Systems (ACIS)': 'acis',
#  'Australasian Conference on Information Systems': 'acis',
#  'IEEE/ACIS International Conference on Computer and Information Science (ICIS)': 'ACISicis',
#  'IEEE/ACIS International Conference on Computer and Information Science': 'ACISicis',
#  'Australasian Conference on Information Security and Privacy (ACISP)': 'acisp',
#  'Australasian Conference on Information Security and Privacy': 'acisp',
#  'Automation, Control, and Information Technology (ACIT)': 'acit',
#  'Automation, Control, and Information Technology': 'acit',
#  'International Conference on Applied Computing and Information Technology (ACIT)': 'acit2',
#  'International Conference on Applied Computing and Information Technology': 'acit2',
#  'Arab Conference on Information Technology (ACIT)': 'acit3',
#  'Arab Conference on Information Technology': 'acit3',
#  'International Conference on Advanced Computer Information Technologies (ACIT)': 'acit4',
#  'International Conference on Advanced Computer Information Technologies': 'acit4',
#  'International Conference on Advances in Computing and Information Technology (ACITY)': 'acity',
#  'International Conference on Advances in Computing and Information Technology': 'acity',
#  'Advanced Concepts for Intelligent Vision Systems Conference (ACIVS)': 'acivs',
#  'Advanced Concepts for Intelligent Vision Systems Conference': 'acivs',
#  'Workshop on Asian Language Resources (ALR)': 'acl-alr',
#  'Workshop on Asian Language Resources': 'acl-alr',
#  'Australasian Language Technology Association Workshop (ALTA)': 'acl-alta',
#  'Australasian Language Technology Association Workshop': 'acl-alta',
#  'Workshop on Online Abuse and Harms (WOAH)': 'acl-alw',
#  'Workshop on Online Abuse and Harms': 'acl-alw',
#  'Workshop on Balto-Slavic Natural Language Processing (BSNLP)': 'acl-bsnlp',
#  'Workshop on Balto-Slavic Natural Language Processing': 'acl-bsnlp',
#  'Workshop on Building and Using Comparable Corpora (BUCC)': 'acl-bucc',
#  'Workshop on Building and Using Comparable Corpora': 'acl-bucc',
#  'Workshop on Computational Linguistics for Linguistic Complexity (CL4LC)': 'acl-cl4lc',
#  'Workshop on Computational Linguistics for Linguistic Complexity': 'acl-cl4lc',
#  'Clinical Natural Language Processing Workshop (ClinicalNLP)': 'acl-clinicalnlp',
#  'Clinical Natural Language Processing Workshop': 'acl-clinicalnlp',
#  'Workshop on Computational Linguistics and Clinical Psychology (CLPsych)': 'acl-clpsych',
#  'Workshop on Computational Linguistics and Clinical Psychology': 'acl-clpsych',
#  'Workshop on Cognitive Modeling and Computational Linguistics (CMCL)': 'acl-cmcl',
#  'Workshop on Cognitive Modeling and Computational Linguistics': 'acl-cmcl',
#  'Workshop on Computational Approaches to Linguistic Code-Switching (CALCS)': 'acl-codeswitch',
#  'Workshop on Computational Approaches to Linguistic Code-Switching': 'acl-codeswitch',
#  'Workshop on NLP for Conversational AI (CovAI)': 'acl-convai',
#  'Workshop on NLP for Conversational AI': 'acl-convai',
#  'Workshop on Continuous Vector Space Models and their Compositionality (CVSC)': 'acl-cvsc',
#  'Workshop on Continuous Vector Space Models and their Compositionality': 'acl-cvsc',
#  'Workshop on Knowledge Extraction and Integration for Deep Learning Architectures; Deep Learning Inside Out (DeeLIO)': 'acl-deelio',
#  'Workshop on Knowledge Extraction and Integration for Deep Learning Architectures; Deep Learning Inside Out': 'acl-deelio',
#  'Workshop on Deep Learning Approaches for Low-Resource Natural Language Processing (DeepLo)': 'acl-deeplo',
#  'Workshop on Deep Learning Approaches for Low-Resource Natural Language Processing': 'acl-deeplo',
#  'Workshop on Document-grounded Dialogue and Conversational Question Answering (DialDoc)': 'acl-dialdoc',
#  'Workshop on Document-grounded Dialogue and Conversational Question Answering': 'acl-dialdoc',
#  'Deep Machine Translation Workshop (DMTW)': 'acl-dmtw',
#  'Deep Machine Translation Workshop': 'acl-dmtw',
#  'Workshop on Figurative Language Processing (Fig-Lang)': 'acl-figlang',
#  'Workshop on Figurative Language Processing': 'acl-figlang',
#  'GEometrical Models of Natural Language Semantics (GEMS)': 'acl-gems',
#  'GEometrical Models of Natural Language Semantics': 'acl-gems',
#  'First Workshop on Insights from Negative Results in NLP (Insights)': 'acl-insights',
#  'First Workshop on Insights from Negative Results in NLP': 'acl-insights',
#  'International Workshop on Paraphrasing (IWP)': 'acl-iwp',
#  'International Workshop on Paraphrasing': 'acl-iwp',
#  'Joint Symposium on Semantic Processing (JSSP)': 'acl-jssp',
#  'Joint Symposium on Semantic Processing': 'acl-jssp',
#  'Workshop on Computational Approaches to Historical Language Change (LChange)': 'acl-lchange',
#  'Workshop on Computational Approaches to Historical Language Change': 'acl-lchange',
#  'Workshop on Linked Data in Linguistics (LDL)': 'acl-ldl',
#  'Workshop on Linked Data in Linguistics': 'acl-ldl',
#  'International Workshop on Linguistically Interpreted Corpora (LINC)': 'acl-linc',
#  'International Workshop on Linguistically Interpreted Corpora': 'acl-linc',
#  'International Workshop on Health Text Mining and Information Analysis (Louhi)': 'acl-louhi',
#  'International Workshop on Health Text Mining and Information Analysis': 'acl-louhi',
#  'Workshop on Machine Reading for Question Answering (MRQA)': 'acl-mrqa',
#  'Workshop on Machine Reading for Question Answering': 'acl-mrqa',
#  'Workshop on Summarization and Summary Evaluation Across Source Types and Genres (MultiLing)': 'acl-multiling',
#  'Workshop on Summarization and Summary Evaluation Across Source Types and Genres': 'acl-multiling',
#  'Natural Legal Language Processing (NLLP)': 'acl-nllp',
#  'Natural Legal Language Processing': 'acl-nllp',
#  'Workshop on NLP and Computational Social Science (NLP+CSS)': 'acl-nlpcss',
#  'Workshop on NLP and Computational Social Science': 'acl-nlpcss',
#  "Workshop on Computational Modeling of People's Opinions, Personality, and Emotions in Social Media (PEOPLES)": 'acl-peoples',
#  "Workshop on Computational Modeling of People's Opinions, Personality, and Emotions in Social Media": 'acl-peoples',
#  'Workshop on Predicting and Improving Text Readability for Target Reader Populations (PITR)': 'acl-pitr',
#  'Workshop on Predicting and Improving Text Readability for Target Reader Populations': 'acl-pitr',
#  "Workshop on the People's Web Meets NLP": 'acl-pwnlp',
#  'Workshop on Computational Approaches to Semitic Languages (SEMITIC)': 'acl-semitic',
#  'Workshop on Computational Approaches to Semitic Languages': 'acl-semitic',
#  'Workshop on Chinese Language Processing (SIGHAN)': 'acl-sighan',
#  'Workshop on Chinese Language Processing': 'acl-sighan',
#  'International Workshop on Natural Language Processing for Social Media (SocialNLP)': 'acl-socialnlp',
#  'International Workshop on Natural Language Processing for Social Media': 'acl-socialnlp',
#  'Workshop on Statistical Parsing of Morphologically Rich Languages (SPMRL)': 'acl-spmrl',
#  'Workshop on Statistical Parsing of Morphologically Rich Languages': 'acl-spmrl',
#  'Workshop on Structured Prediction for NLP (SPNLP)': 'acl-spnlp',
#  'Workshop on Structured Prediction for NLP': 'acl-spnlp',
#  'Conference on Semantics in Text Processing (STEP)': 'acl-step',
#  'Conference on Semantics in Text Processing': 'acl-step',
#  'Workshop on Semantic Web and Information Extraction (SWAIE)': 'acl-swaie',
#  'Workshop on Semantic Web and Information Extraction': 'acl-swaie',
#  'Workshop on Natural Language Processing Techniques for Educational Applications (NLP-TEA)': 'acl-tea',
#  'Workshop on Natural Language Processing Techniques for Educational Applications': 'acl-tea',
#  'Workshop on Trolling, Aggression and Cyberbullying (TRAC)': 'acl-trac',
#  'Workshop on Trolling, Aggression and Cyberbullying': 'acl-trac',
#  'Workshop on Vision and Language (VL)': 'acl-vl',
#  'Workshop on Vision and Language': 'acl-vl',
#  'Workshop on Very Large Corpora (VLC)': 'acl-vlc',
#  'Workshop on Very Large Corpora': 'acl-vlc',
#  'Widening NLP Workshop': 'acl-wnlp',
#  'ACL Workshops (ACL Workshops)': 'acl-workshops',
#  'ACL Workshops': 'acl-workshops',
#  'Workshop on NLP and XML': 'acl-xml',
#  'Annual Meeting of the Association for Computational Linguistics (ACL)': 'acl',
#  'Annual Meeting of the Association for Computational Linguistics': 'acl',
#  'International Workshop on the ACL2 Theorem Prover and Its Applications (ACL2)': 'acl2',
#  'International Workshop on the ACL2 Theorem Prover and Its Applications': 'acl2',
#  'Workshop on EVENTS: Definition, Detection, Coreference, and Representation (EVENTS)': 'aclevents',
#  'Workshop on EVENTS: Definition, Detection, Coreference, and Representation': 'aclevents',
#  'International Conference on AI in Computational Linguistics (ACLING)': 'acling',
#  'International Conference on AI in Computational Linguistics': 'acling',
#  'Linguistic Annotation Workshop (LAW)': 'acllaw',
#  'Linguistic Annotation Workshop': 'acllaw',
#  'Named Entity Workshop (NEWS)': 'aclnews',
#  'Named Entity Workshop': 'aclnews',
#  'Workshop on Neural Generation and Translation (NGT)': 'aclnmt',
#  'Workshop on Neural Generation and Translation': 'aclnmt',
#  'Workshop on Noisy User-generated Text (NUT)': 'aclnut',
#  'Workshop on Noisy User-generated Text': 'aclnut',
#  'Universal Dependencies Workshop (UDW)': 'acludw',
#  'Universal Dependencies Workshop': 'acludw',
#  'Workshop on Web as Corpus (WAC)': 'aclwac',
#  'Workshop on Web as Corpus': 'aclwac',
#  'Workshop on Asian Translation (WAT)': 'aclwat',
#  'Workshop on Asian Translation': 'aclwat',
#  'ACM Annual Conference': 'acm',
#  'Algorithms, Computing and Mathematics Conference (ACM)': 'acm2',
#  'Algorithms, Computing and Mathematics Conference': 'acm2',
#  'International Conference on Advances in Computer Entertainment Technology (ACE)': 'ACMace',
#  'International Conference on Advances in Computer Entertainment Technology': 'ACMace',
#  'ACM Workshop on Blockchains, Cryptocurrencies and Contracts (BCC)': 'acmbcc',
#  'ACM Workshop on Blockchains, Cryptocurrencies and Contracts': 'acmbcc',
#  'ACM Annual Conference on Computer Science (CSC)': 'acmcsc',
#  'ACM Annual Conference on Computer Science': 'acmcsc',
#  'Conference on Designing Interactive Systems (DIS)': 'ACMdis',
#  'Conference on Designing Interactive Systems': 'ACMdis',
#  'ACM Europe Summer School (ACM Europe Summer School)': 'acmeas',
#  'ACM Europe Summer School': 'acmeas',
#  'International Conference on Innovative Computing and Cloud Computing (ICCC)': 'acmiccc',
#  'International Conference on Innovative Computing and Cloud Computing': 'acmiccc',
#  'International Conference on Electronic Commerce (ICEC)': 'ACMicec',
#  'International Conference on Electronic Commerce': 'ACMicec',
#  'Information-Centric Networking (ICN)': 'acmicn',
#  'Information-Centric Networking': 'acmicn',
#  'International Conference on Interaction Design and Children (IDC)': 'acmidc',
#  'International Conference on Interaction Design and Children': 'acmidc',
#  'Asian Conference on Machine Learning (ACML)': 'acml',
#  'Asian Conference on Machine Learning': 'acml',
#  'Algebraic and Coalgebraic Methods in the Mathematics of Program Construction': 'acmmpc',
#  'Memory System Performance and Correctness (MSP)': 'ACMmsp',
#  'Memory System Performance and Correctness': 'ACMmsp',
#  'ACM Policy': 'ACMpolicy',
#  'International Conference on Analytical and Computational Methods in Probability Theory (ACMPT)': 'acmpt',
#  'International Conference on Analytical and Computational Methods in Probability Theory': 'acmpt',
#  'ACM Conference on Reproducibility and Replicability (ACM-REP)': 'acmrep',
#  'ACM Conference on Reproducibility and Replicability': 'acmrep',
#  'ACM Southeast Regional Conference': 'ACMse',
#  'ACM Symposium on Graphic Languages': 'acmsgl',
#  'ACM Turing Celebration Conference (ACM TUR-C)': 'acmturc',
#  'ACM Turing Celebration Conference': 'acmturc',
#  'International Conference on Advanced Communication and Networking (ACN)': 'acn',
#  'International Conference on Advanced Communication and Networking': 'acn',
#  'International Conference on Applied Cryptography and Network Security (ACNS)': 'acns',
#  'International Conference on Applied Cryptography and Network Security': 'acns',
#  'Agent Communication (AC)': 'acom',
#  'Agent Communication': 'acom',
#  'International Conference on Advanced Computing and Analytics (ACOMPA)': 'acomp',
#  'International Conference on Advanced Computing and Analytics': 'acomp',
#  'International Conference on Advanced Communication Systems and Information Security (ACOSIS)': 'acosis',
#  'International Conference on Advanced Communication Systems and Information Security': 'acosis',
#  'International Workshop on Automated Configuration and Tailoring of Applications (ACoTA)': 'acota',
#  'International Workshop on Automated Configuration and Tailoring of Applications': 'acota',
#  'Workshop on Aspects, Components, and Patterns for Infrastructure Software (ACP4IS)': 'acp4is',
#  'Workshop on Aspects, Components, and Patterns for Infrastructure Software': 'acp4is',
#  'ACPC Conference (ACPC)': 'acpc',
#  'ACPC Conference': 'acpc',
#  'Asian Conference on Pattern Recognition (ACPR)': 'acpr',
#  'Asian Conference on Pattern Recognition': 'acpr',
#  'International Conference on Advances in Computing Research (ACR)': 'acr',
#  'International Conference on Advances in Computing Research': 'acr',
#  'International Conference on Cellular Automata for Research and Industry (ACRI)': 'acri',
#  'International Conference on Cellular Automata for Research and Industry': 'acri',
#  'International Conference on Applied Computing to Support Industry: Innovation and Technology (ACRIT)': 'acrit',
#  'International Conference on Applied Computing to Support Industry: Innovation and Technology': 'acrit',
#  'The Analysis of Concurrent Systems': 'acs',
#  'International Conference on Advanced Computer Systems (ACS)': 'acs2',
#  'International Conference on Advanced Computer Systems': 'acs2',
#  'Annual Computer Security Applications Conference (ACSAC)': 'acsac',
#  'Annual Computer Security Applications Conference': 'acsac',
#  'Australasian Computer Science Conference (ACSC)': 'acsc',
#  'Australasian Computer Science Conference': 'acsc',
#  'International Conference on Application of Concurrency to System Design (ACSD)': 'acsd',
#  'International Conference on Application of Concurrency to System Design': 'acsd',
#  'Australasian Conference on Computer Science Education (ACSE)': 'acse',
#  'Australasian Conference on Computer Science Education': 'acse',
#  'International Conference on Autonomic Computing and Self-Organizing Systems (ACSOS)': 'acsos',
#  'International Conference on Autonomic Computing and Self-Organizing Systems': 'acsos',
#  'International Doctoral Symposium on Applied Computation and Security Systems (ACSS)': 'acss',
#  'International Doctoral Symposium on Applied Computation and Security Systems': 'acss',
#  'Asilomar Conference on Signals, Systems and Computers (ACSCC)': 'acssc',
#  'Asilomar Conference on Signals, Systems and Computers': 'acssc',
#  'Advances in Computer Science and Technology (ACST)': 'acst',
#  'Advances in Computer Science and Technology': 'acst',
#  'Australasian Computer Science Week (ACSW)': 'acsw',
#  'Australasian Computer Science Week': 'acsw',
#  'Applied Category Theory (ACT)': 'act',
#  'Applied Category Theory': 'act',
#  'International Conference on Advances in Computational Tools for Engineering Applications (ACTEA)': 'actea',
#  'International Conference on Advances in Computational Tools for Engineering Applications': 'actea',
#  'International Conference on Wireless Technologies for Humanitarian Relief (ACWR)': 'acwr',
#  'International Conference on Wireless Technologies for Humanitarian Relief': 'acwr',
#  'Workshop on Adaptive AIoT Systems (AdaAIoTSys)': 'adaaiotsys',
#  'Workshop on Adaptive AIoT Systems': 'adaaiotsys',
#  'Ada Deutschland Tagung': 'adaD',
#  'International Conference on Reliable Software Technologies (Ada-Europe)': 'adaEurope',
#  'International Conference on Reliable Software Technologies': 'adaEurope',
#  'The Adaptive Web': 'adaptive',
#  'AdaTEC Conference on Ada': 'adatec',
#  'Applications of Databases (ADB)': 'adb',
#  'Applications of Databases': 'adb',
#  'Symposium on Advances in Databases and Information Systems (ADBIS)': 'adbis',
#  'Symposium on Advances in Databases and Information Systems': 'adbis',
#  'Advances in Data Base Theory (ADBT)': 'adbt',
#  'Advances in Data Base Theory': 'adbt',
#  'Australasian Database Conference (ADC)': 'adc',
#  'Australasian Database Conference': 'adc',
#  'Application and Development of Computer Games (ADCOG)': 'adcog',
#  'Application and Development of Computer Games': 'adcog',
#  'International Conference on Advanced Computing, Networking and Security (ADCONS)': 'adcons',
#  'International Conference on Advanced Computing, Networking and Security': 'adcons',
#  'Australasian Document Computing Symposium (ADCS)': 'adcs',
#  'Australasian Document Computing Symposium': 'adcs',
#  'Automated Deduction in Geometry (ADG)': 'adg',
#  'Automated Deduction in Geometry': 'adg',
#  'International Conference on Advanced Hybrid Information Processing (ADHIP)': 'adhip',
#  'International Conference on Advanced Hybrid Information Processing': 'adhip',
#  'International Conference on Ad-Hoc, Mobile and Wireless Networks (ADHOC-NOW)': 'adhoc-now',
#  'International Conference on Ad-Hoc, Mobile and Wireless Networks': 'adhoc-now',
#  'International ICST Conference on Ad Hoc Network and Tools for ITs (ADHOCNETS)': 'adhocnets',
#  'International ICST Conference on Ad Hoc Network and Tools for ITs': 'adhocnets',
#  'IFAC Conference on Analysis and Design of Hybrid Systems (ADHS)': 'adhs',
#  'IFAC Conference on Analysis and Design of Hybrid Systems': 'adhs',
#  'International Workshop on Attacks and Defenses for the Internet-of-Things (ADIoT)': 'adiot',
#  'International Workshop on Attacks and Defenses for the Internet-of-Things': 'adiot',
#  'Apoyo a la Decisión en Ingeniería del Software (ADIS)': 'adis',
#  'Apoyo a la Decisión en Ingeniería del Software': 'adis',
#  'Decision Support in Software Engineering': 'adis',
#  'Workshop on Data Mining for Online Advertising (AdKDD)': 'adkdd',
#  'Workshop on Data Mining for Online Advertising': 'adkdd',
#  'IEEE Advances in Digital Libraries (ADL)': 'adl',
#  'Forum on Research & Technology Advances in Digital Libraries': 'adl',
#  'IEEE Advances in Digital Libraries': 'adl',
#  'International Conference on Advanced Data Mining and Applications (ADMA)': 'adma',
#  'International Conference on Advanced Data Mining and Applications': 'adma',
#  'Agents and Data Mining Interaction (ADMI)': 'admi',
#  'Agents and Data Mining Interaction': 'admi',
#  'International Conference on Algorithms, Data Mining, and Information Technology (ADMIT)': 'admit',
#  'International Conference on Algorithms, Data Mining, and Information Technology': 'admit',
#  'International Workshop on Accelerating Data Management Systems Using Modern Processor and Storage Architectures (ADMS)': 'adms',
#  'International Workshop on Accelerating Data Management Systems Using Modern Processor and Storage Architectures': 'adms',
#  'Advances in New Technologies, Interactive Interfaces, and Communicability (ADNTIIC)': 'adntiic',
#  'Advances in New Technologies, Interactive Interfaces, and Communicability': 'adntiic',
#  'International Workshop on Algorithms of Data Processing (ADP)': 'adp',
#  'International Workshop on Algorithms of Data Processing': 'adp',
#  'IEEE Symposium on Adaptive Dynamic Programming and Reinforcement Learning (ADPRL)': 'adprl',
#  'IEEE Symposium on Adaptive Dynamic Programming and Reinforcement Learning': 'adprl',
#  'Affective Dialogue Systems (ADS)': 'ads',
#  'Affective Dialogue Systems': 'ads',
#  'Workshop on Recent Trends in Algebraic Development Techniques (WADT)': 'adt',
#  'Workshop on Recent Trends in Algebraic Development Techniques': 'adt',
#  'International Workshop on Advanced Applied Information Technologies (AdbAIT)': 'advait',
#  'International Workshop on Advanced Applied Information Technologies': 'advait',
#  'Advances in Information Systems (ADVIS)': 'advis',
#  'Advances in Information Systems': 'advis',
#  'Evolution Artificielle (EA)': 'ae',
#  'Artificial Evolution (AE)': 'ae',
#  'Evolution Artificielle': 'ae',
#  'Artificial Evolution': 'ae',
#  'International Workshop on Augmented Environments for Computer-Assisted Interventions (AE-CAI)': 'aecai-ws',
#  'International Workshop on Augmented Environments for Computer-Assisted Interventions': 'aecai-ws',
#  'Afro-European Conference for Industrial Advancement (AECIA)': 'aecia',
#  'Afro-European Conference for Industrial Advancement': 'aecia',
#  'International Workshop on Agents for Educational Games and Simulations (AEGS)': 'aegs',
#  'International Workshop on Agents for Educational Games and Simulations': 'aegs',
#  'Workshop on Fairness and Bias in AI (AEQUITAS)': 'aequitas',
#  'Workshop on Fairness and Bias in AI': 'aequitas',
#  'International Conference on Advanced Encryption Standard (AES)': 'aes',
#  'International Conference on Advanced Encryption Standard': 'aes',
#  'Workshop on Affective Computing and Context Awareness in Ambient Intelligence (AfCAI)': 'afcai',
#  'Workshop on Affective Computing and Context Awareness in Ambient Intelligence': 'afcai',
#  'Algorithmic Fairness through the Lens of Time Workshop (AFT)': 'afci',
#  'Algorithmic Fairness through the Lens of Time Workshop': 'afci',
#  'International Workshop on Affective Computing for Requirements Engineering (AffectRE)': 'affectre-ws',
#  'International Workshop on Affective Computing for Requirements Engineering': 'affectre-ws',
#  'Affective Interaction in Natural Environments (AFFINE)': 'affine',
#  'Affective Interaction in Natural Environments': 'affine',
#  'International Workshop on Affective-Aware Virtual Agents and Social Robots (AFFINE)': 'affine2',
#  'International Workshop on Affective-Aware Virtual Agents and Social Robots': 'affine2',
#  'AFIPS National Computer Conferences (AFIPS NCC)': 'afips',
#  'AFIPS National Computer Conferences': 'afips',
#  'American Federation of Information Processing Societies National Computer Conferences': 'afips',
#  'International Conference on Automata and Formal Languages (AFL)': 'afl',
#  'International Conference on Automata and Formal Languages': 'afl',
#  'Advanced Functional Programming School (AFP)': 'afp',
#  'Advanced Functional Programming School': 'afp',
#  'Algebraic Frames for the Perception-Action Cycle (AFPAC)': 'afpac',
#  'Algebraic Frames for the Perception-Action Cycle': 'afpac',
#  'International Conference on Cryptology in Africa (AFRICACRYPT)': 'africacrypt',
#  'International Conference on Cryptology in Africa': 'africacrypt',
#  'Workshop on African Natural Language Processing (AfricaNLP)': 'africanlp',
#  'Workshop on African Natural Language Processing': 'africanlp',
#  'International Conference on Emerging Technologies for Developing Countries (AFRICATEK)': 'africatek',
#  'International Conference on Emerging Technologies for Developing Countries': 'africatek',
#  'African Conference on Human Computer Interaction (AfriCHI)': 'africhi',
#  'African Conference on Human Computer Interaction': 'africhi',
#  'International Conference on e-Infrastructure and e-Services for Developing Countries (AFRICOMM)': 'africom',
#  'International Conference on e-Infrastructure and e-Services for Developing Countries': 'africom',
#  'IEEE AFRICON (AFRICON)': 'africon',
#  'IEEE AFRICON': 'africon',
#  'IEEE Region 8 Conference AFRICON': 'africon',
#  'International Conference on Computer Graphics, Virtual Reality, Visualisation and Interaction in Africa (Afrigraph)': 'afrigraph',
#  'International Conference on Computer Graphics, Virtual Reality, Visualisation and Interaction in Africa': 'afrigraph',
#  'Advances in Soft Computing (AFSS)': 'afss',
#  'Advances in Soft Computing': 'afss',
#  'Conference on Advances in Financial Technologies (AFT)': 'aft',
#  'Conference on Advances in Financial Technologies': 'aft',
#  'Advanced Geographic Data Modelling (AGDM)': 'agdm',
#  'Advanced Geographic Data Modelling': 'agdm',
#  'Issues in Agent Communication': 'agentCL',
#  'Special Interest Group on Intelligent Information Agents Meeting (AgentLink)': 'agentlink',
#  'Special Interest Group on Intelligent Information Agents Meeting': 'agentlink',
#  'International Conference on Autonomous Agents (Agents)': 'agents',
#  'International Conference on Autonomous Agents': 'agents',
#  'Workshop on Programming based on Actors, Agents, and Decentralized Control (AGERE!)': 'agere',
#  'Workshop on Programming based on Actors, Agents, and Decentralized Control': 'agere',
#  'Conference on Artificial General Intelligence (AGI)': 'agi',
#  'Conference on Artificial General Intelligence': 'agi',
#  'AGILE Conference on Geographic Information Science (AGILE)': 'agile',
#  'AGILE Conference on Geographic Information Science': 'agile',
#  'Agile Conference (AGILE)': 'agiledc',
#  'Agile Conference': 'agiledc',
#  'PhD School of the Association of Geographic Information Laboratories for Europe (AGILE PhD School)': 'agilephd',
#  'PhD School of the Association of Geographic Information Laboratories for Europe': 'agilephd',
#  'International Summer School on Aggregation Operators (AGOP)': 'agop',
#  'International Summer School on Aggregation Operators': 'agop',
#  'APPIA-GULP-PRODE Joint Conference on Declarative Programming (AGP)': 'agp',
#  'APPIA-GULP-PRODE Joint Conference on Declarative Programming': 'agp',
#  'International Conference on Agro-Geoinformatics (Agro-Geoinformatics)': 'agro-geoinformatics',
#  'International Conference on Agro-Geoinformatics': 'agro-geoinformatics',
#  'Agents for Games and Simulations (AGS)': 'ags',
#  'Agents for Games and Simulations': 'ags',
#  'Applications of Graph Transformations with Industrial Relevance (AGTIVE)': 'agtive',
#  'Applications of Graph Transformations with Industrial Relevance': 'agtive',
#  'International Conference on User Modeling, Adaptation, and Personalization (UMAP)': 'ah',
#  'International Conference on User Modeling, Adaptation, and Personalization': 'ah',
#  'Advances in Neuroergonomics and Cognitive Engineering (AHFE)': 'ahfe',
#  'Advances in Neuroergonomics and Cognitive Engineering': 'ahfe',
#  'International Conference on Algorithms, High Performance Computing and Artificial Intelligence (ALT)': 'ahpcai',
#  'International Conference on Algorithms, High Performance Computing and Artificial Intelligence': 'ahpcai',
#  'NASA/ESA Conference on Adaptive Hardware and Systems (AHS)': 'ahs',
#  'NASA/ESA Conference on Adaptive Hardware and Systems': 'ahs',
#  'International Workshop on Artificial Intelligence for Signal, Image Processing and Multimedia (AI-SIPM)': 'ai-sipm',
#  'International Workshop on Artificial Intelligence for Signal, Image Processing and Multimedia': 'ai-sipm',
#  'Canadian Conference on Artificial Intelligence (Canadian AI)': 'ai',
#  'Canadian Conference on Artificial Intelligence': 'ai',
#  'International Conference on Artificial Intelligence, Automation and Algorithms (AI2A)': 'ai2a',
#  'International Conference on Artificial Intelligence, Automation and Algorithms': 'ai2a',
#  'Workshop on Advances in Argumentation in Artificial Intelligence (AI³)': 'ai3',
#  'Workshop on Advances in Argumentation in Artificial Intelligence': 'ai3',
#  'Workshop on AI for Digital Twins and Cyber-Physical Applications (AI4DT&CP)': 'ai4dt',
#  'Workshop on AI for Digital Twins and Cyber-Physical Applications': 'ai4dt',
#  'International Conference on Artificial Intelligence for Global Security (AI4GS)': 'ai4gs',
#  'International Conference on Artificial Intelligence for Global Security': 'ai4gs',
#  'International Conference on Artificial Intelligence for Industries (AI4I)': 'ai4i',
#  'International Conference on Artificial Intelligence for Industries': 'ai4i',
#  'International Workshop on Artificial Intelligence for Knowledge Management, Energy, and Sustainability (AI4KMES)': 'ai4kmes',
#  'International Workshop on Artificial Intelligence for Knowledge Management, Energy, and Sustainability': 'ai4kmes',
#  'International Workshop on Artificial Intelligence and Machine Learning for Scientific Applications (AI4S)': 'ai4s',
#  'International Workshop on Artificial Intelligence and Machine Learning for Scientific Applications': 'ai4s',
#  '50 Years of Artificial Intelligence (AI@50)': 'ai50',
#  '50 Years of Artificial Intelligence': 'ai50',
#  'Artificial Intelligence and Applications (AIA)': 'aia',
#  'Artificial Intelligence and Applications': 'aia',
#  'IFIP International Conference on Artificial Intelligence Applications and Innovations (AIAI)': 'aiai',
#  'IFIP International Conference on Artificial Intelligence Applications and Innovations': 'aiai',
#  'International Conference on Artificial Intelligence and Advanced Manufacturing (AIAM)': 'aiam',
#  'International Conference on Artificial Intelligence and Advanced Manufacturing': 'aiam',
#  'International Research School in Artificial Intelligence in Bergen (AIB)': 'aib',
#  'International Research School in Artificial Intelligence in Bergen': 'aib',
#  'Guangdong - Hong Kong - Macao Greater Bay Area Artificial Intelligence and Big Data Forum (AIBDF)': 'aibdf',
#  'Guangdong - Hong Kong - Macao Greater Bay Area Artificial Intelligence and Big Data Forum': 'aibdf',
#  'International Conference on Artificial Intelligence, Blockchain, and Internet of Things (AIBThings)': 'aibthings',
#  'International Conference on Artificial Intelligence, Blockchain, and Internet of Things': 'aibthings',
#  'International Workshop on Artificial Intelligence and Cognition (AIC)': 'aic',
#  'International Workshop on Artificial Intelligence and Cognition': 'aic',
#  'International Conference on Artificial Intelligence Circuits and Systems (AICAS)': 'aicas',
#  'International Conference on Artificial Intelligence Circuits and Systems': 'aicas',
#  'Artificial Intelligence and Cloud Computing Conference (AICCC)': 'aiccc',
#  'Artificial Intelligence and Cloud Computing Conference': 'aiccc',
#  'Cognitive Models and Artificial Intelligence Conference (AICCONF)': 'aicconf',
#  'Cognitive Models and Artificial Intelligence Conference': 'aicconf',
#  'ACS/IEEE International Conference on Computer Systems and Applications (AICCSA)': 'aiccsa',
#  'ACS/IEEE International Conference on Computer Systems and Applications': 'aiccsa',
#  'Artificial Intelligence and Computational Intelligence (AICI)': 'aici',
#  'Artificial Intelligence and Computational Intelligence': 'aici',
#  'International Workshop on AI Approaches to the Complexity of Legal Systems (AICOL)': 'aicol',
#  'International Workshop on AI Approaches to the Complexity of Legal Systems': 'aicol',
#  'Irish Conference on Artificial Intelligence and Cognitive Science (AICS)': 'aics',
#  'Irish Conference on Artificial Intelligence and Cognitive Science': 'aics',
#  'International Conference on Artificial Intelligence for Cyber Security Systems and Privacy (AICSP)': 'aicsp',
#  'International Conference on Artificial Intelligence for Cyber Security Systems and Privacy': 'aicsp',
#  'Advanced Industrial Conference on Telecommunications (AICT)': 'aict',
#  'Advanced Industrial Conference on Telecommunications': 'aict',
#  'International Workshop on Advanced Information and Computation Technologies and Systems (AICTS)': 'aicts',
#  'International Workshop on Advanced Information and Computation Technologies and Systems': 'aicts',
#  'Applications of Invariance in Computer Vision': 'aicv',
#  'International Conferences on Artificial Intelligence and Computer Vision (AICV)': 'aicv2',
#  'International Conferences on Artificial Intelligence and Computer Vision': 'aicv2',
#  'International Conference on Artificial Intelligence in Design (AID)': 'aid',
#  'International Conference on Artificial Intelligence in Design': 'aid',
#  'Workshop on Artificial Intelligence Diversity, Belonging, Equity, and Inclusion (AIDBEI)': 'aidbei',
#  'Workshop on Artificial Intelligence Diversity, Belonging, Equity, and Inclusion': 'aidbei',
#  'Workshop in Exploiting AI Techniques for Data Management (aiDM)': 'aidm',
#  'Workshop in Exploiting AI Techniques for Data Management': 'aidm',
#  'Conference on Artificial Intelligence for Data Discovery and Reuse (AIDR)': 'aidr',
#  'Conference on Artificial Intelligence for Data Discovery and Reuse': 'aidr',
#  'Workshop on Implementing AI Ethics through a Behavioural Lens (AIEB)': 'aieb',
#  'Workshop on Implementing AI Ethics through a Behavioural Lens': 'aieb',
#  'International Conference on Artificial Intelligence in Education (AIED)': 'aied',
#  'International Conference on Artificial Intelligence in Education': 'aied',
#  'International Conference on Artificial Intelligence in Electronics Engineering (AIEE)': 'aiee',
#  'International Conference on Artificial Intelligence in Electronics Engineering': 'aiee',
#  'IRE-AIEE-ACM Computer Conference': 'aieeire',
#  'International Workshop on Automated Information Extraction in Media Production (AIEMPro)': 'aiempro',
#  'International Workshop on Automated Information Extraction in Media Production': 'aiempro',
#  'AAAI/ACM Conference on AI, Ethics, and Society (AIES)': 'aies',
#  'AAAI/ACM Conference on AI, Ethics, and Society': 'aies',
#  'Artificial Intelligence from the Information Processing Perspective (AIFIPP)': 'aifipp',
#  'Artificial Intelligence from the Information Processing Perspective': 'aifipp',
#  'International Workshop on Artificial Intelligence in Grid Computing (AIGC)': 'aigc',
#  'International Workshop on Artificial Intelligence in Grid Computing': 'aigc',
#  'Workshop on Artificial Intelligence Governance Ethics and Law (AIGEL)': 'aigel',
#  'Workshop on Artificial Intelligence Governance Ethics and Law': 'aigel',
#  'Artifical Intelligence for Human Computing': 'aihc',
#  'International Workshop on Analogical and Inductive Inference (AII)': 'aii',
#  'International Workshop on Analogical and Inductive Inference': 'aii',
#  'International Conference on Applied Intelligence and Informatics (AII)': 'aii2',
#  'International Conference on Applied Intelligence and Informatics': 'aii2',
#  'International Conference of the Italian Association for Artificial Intelligence (AI*IA)': 'aiia',
#  'International Conference of the Italian Association for Artificial Intelligence': 'aiia',
#  'AAAI Conference on Artificial Intelligence and Interactive Digital Entertainment Conference (AIIDE)': 'aiide',
#  'AAAI Conference on Artificial Intelligence and Interactive Digital Entertainment Conference': 'aiide',
#  'International Conference on Artificial Intelligence in Healthcare (AIiH)': 'aiih',
#  'International Conference on Artificial Intelligence in Healthcare': 'aiih',
#  'International Conferenc on Artificial Intelligence over Infrared Images for Medical Applications (AIIIMA)': 'aiiima',
#  'International Conferenc on Artificial Intelligence over Infrared Images for Medical Applications': 'aiiima',
#  'World AI IoT Congress (AIIoT)': 'aiiot',
#  'World AI IoT Congress': 'aiiot',
#  'International Conferences on Artificial Intelligence, Information Processing and Cloud Computing (AIIPCC)': 'aiipcc',
#  'International Conferences on Artificial Intelligence, Information Processing and Cloud Computing': 'aiipcc',
#  'International Conference on Artificial Intelligence and Knowledge Engineering (AIKE)': 'aike',
#  'International Conference on Artificial Intelligence and Knowledge Engineering': 'aike',
#  'International Conference on Artificial Intelligence Logic and Applications (AILA)': 'aila',
#  'International Conference on Artificial Intelligence Logic and Applications': 'aila',
#  'Conference of the Association Information and Management (AIM)': 'aim',
#  'Conference of the Association Information and Management': 'aim',
#  'International Workshop on Automated Incident Management in Cloud (AIMC)': 'aimc',
#  'International Workshop on Automated Incident Management in Cloud': 'aimc',
#  'Conference on Artificial Intelligence in Medicine and Medical Decision Making (AIMDM)': 'aimdm',
#  'Conference on Artificial Intelligence in Medicine and Medical Decision Making': 'aimdm',
#  'International Conference on Artificial Intelligence in Medicine (AIME)': 'aime',
#  'International Conference on Artificial Intelligence in Medicine': 'aime',
#  'IEEE International Conference on Advanced Intelligent Mechatronics (AIM)': 'aimech',
#  'IEEE International Conference on Advanced Intelligent Mechatronics': 'aimech',
#  'Advances in Modal Logic (AiML)': 'aiml',
#  'Advances in Modal Logic': 'aiml',
#  'International Conference on AI-ML-Systems (AIMLSystems)': 'aiml2',
#  'International Conference on AI-ML-Systems': 'aiml2',
#  'Asia Conference on Artificial Intelligence, Machine Learning and Robotics (AIMLR)': 'aimlr',
#  'Asia Conference on Artificial Intelligence, Machine Learning and Robotics': 'aimlr',
#  'Workshop on AI bias: Measurements, Mitigation, Explanation Strategies (AIMMES)': 'aimmes',
#  'Workshop on AI bias: Measurements, Mitigation, Explanation Strategies': 'aimmes',
#  'International Conference on AI & Mobile Services (AIMS)': 'aims-ws',
#  'International Conference on AI & Mobile Services': 'aims-ws',
#  'IFIP International Conference on Autonomous Infrastructure, Management and Security (AIMS)': 'aims',
#  'IFIP International Conference on Autonomous Infrastructure, Management and Security': 'aims',
#  'International Conference on AI and Multimodal Services (AIMS)': 'aims2',
#  'International Conference on AI and Multimodal Services': 'aims2',
#  'Artificial Intelligence: Methodology, Systems, Applications (AIMSA)': 'aimsa',
#  'Artificial Intelligence: Methodology, Systems, Applications': 'aimsa',
#  'International Conference on AI and Metaverse in Supply Chain Management (AIMSCM)': 'aimscm',
#  'International Conference on AI and Metaverse in Supply Chain Management': 'aimscm',
#  'International Conference on Advanced Information Networking and Applications (AINA)': 'aina',
#  'International Conference on Advanced Information Networking and Applications': 'aina',
# ...
#  'Allerton Conference on Communication, Control, and Computing': 'allerton',
#  'International Workshop on Algorithms and Models for Distributed Event Processing (AlMoDEP)': 'almodep',
#  'International Workshop on Algorithms and Models for Distributed Event Processing': 'almodep',
#  'International Conference on Algebraic and Logic Programming (ALP)': 'alp',
#  'International Conference on Algebraic and Logic Programming': 'alp',
#  'Advanced Language Processing and Web Information Technology (ALPIT)': 'alpit',
#  'Advanced Language Processing and Web Information Technology': 'alpit',
#  'UK Conference on Logic Programming (ALPUK)': 'alpuk',
#  'UK Conference on Logic Programming': 'alpuk',
#  'Annual Linux Showcase & Conference': 'alsc',
#  'International Conference on Algorithmic Learning Theory (ALT)': 'alt',
#  'International Conference on Algorithmic Learning Theory': 'alt',
#  'Workshop on Augmented Intelligence for Technology-Assisted Reviews Systems (ALTARS)': 'altars',
#  'Workshop on Augmented Intelligence for Technology-Assisted Reviews Systems': 'altars',
#  'International Workshop on Multimedia Alternate Realities (AltMM)': 'altmm',
#  'International Workshop on Multimedia Alternate Realities': 'altmm',
#  'International Conference and Workshop on Agglutanative Language Technologies as a Challenge of Natural Language Processing (ALTNLP)': 'altnlp',
#  'International Conference and Workshop on Agglutanative Language Technologies as a Challenge of Natural Language Processing': 'altnlp',
#  'Algebraic Logic and Universal Algebra in Computer Science': 'aluacs',
#  'Algebraic Methods': 'am',
#  'International Conference on Algebraic Methodology and Software Technology (AMAST)': 'amast',
#  'International Conference on Algebraic Methodology and Software Technology': 'amast',
#  'International ICST Conference on Ambient Media and Systems (AMBI-SYS)': 'ambisys',
#  'International ICST Conference on Ambient Media and Systems': 'ambisys',
#  'Workshop on Advanced Methodologies for Bayesian Networks (AMBN)': 'ambn',
#  'Workshop on Advanced Methodologies for Bayesian Networks': 'ambn',
#  'Workshop on Advanced Multimedia Computing for Smart Manufacturing and Engineering (AMC-SME)': 'amc-sme',
#  'Workshop on Advanced Multimedia Computing for Smart Manufacturing and Engineering': 'amc-sme',
#  'International Workshop on Advanced Motion Control (AMC)': 'amc',
#  'International Workshop on Advanced Motion Control': 'amc',
#  'American Control Conference (ACC)': 'amcc',
#  'American Control Conference': 'amcc',
#  'Americas Conference on Information Systems (AMCIS)': 'amcis',
#  'Americas Conference on Information Systems': 'amcis',
#  'Advanced Multimedia Content Processing (AMCP)': 'amcp',
#  'Advanced Multimedia Content Processing': 'amcp',
#  'Algorithmic Mathematics and Computer Science (AMCS)': 'amcs',
#  'Algorithmic Mathematics and Computer Science': 'amcs',
#  'Articulated Motion and Deformable Objects (AMDO)': 'amdo',
#  'Articulated Motion and Deformable Objects': 'amdo',
#  'International Workshop on Agent-Mediated Electronic Commerce and Trading Agents Design and Analysis (AMEC/TADA)': 'amec',
#  'International Workshop on Agent-Mediated Electronic Commerce and Trading Agents Design and Analysis': 'amec',
#  'Agent Mediated Electronic Trading (AMET)': 'amet',
#  'Agent Mediated Electronic Trading': 'amet',
#  'Anthropomorphic Motion Factory': 'amf',
#  'Analysis and Modeling of Faces and Gestures (AMFG)': 'amfg',
#  'Analysis and Modeling of Faces and Gestures': 'amfg',
#  'European Conference on Ambient Intelligence (AmI)': 'ami',
#  'European Conference on Ambient Intelligence': 'ami',
#  'American Medical Informatics Association Annual Symposium (AMIA)': 'amia',
#  'American Medical Informatics Association Annual Symposium': 'amia',
#  'International Workshop on Accessibility and Multimodal Interaction Design Approaches in Museums for People with Impairments (AMID)': 'amid',
#  'International Workshop on Accessibility and Multimodal Interaction Design Approaches in Museums for People with Impairments': 'amid',
#  'Ambient Intelligence Forum (AMIF)': 'amif',
#  'Ambient Intelligence Forum': 'amif',
#  'International Conference on Ambient Intelligence for Health (AmIHEALTH)': 'amihealth',
#  'International Conference on Ambient Intelligence for Health': 'amihealth',
#  'Active Mining (AM)': 'amining',
#  'Active Mining': 'amining',
#  'Autonomous Minirobots for Research and Edutainment (AMiRE)': 'amire',
#  'Autonomous Minirobots for Research and Edutainment': 'amire',
#  'Agent Mediated Knowledge Management (AMKM)': 'amkm',
#  'Agent Mediated Knowledge Management': 'amkm',
#  'International Conference on Applied Machine Learning and Data Analytics (AMLDA)': 'amlda',
#  'International Conference on Applied Machine Learning and Data Analytics': 'amlda',
#  'International Conference on Advanced Machine Learning Technologies and Applications (AMLTA)': 'amlta',
#  'International Conference on Advanced Machine Learning Technologies and Applications': 'amlta',
#  'Workshop on Applied Machine Learning Methods for Time Series Forecasting (AMLTS)': 'amlts',
#  'Workshop on Applied Machine Learning Methods for Time Series Forecasting': 'amlts',
#  'Auctions, Market Mechanisms and Their Applications (AMMA)': 'amma',
#  'Auctions, Market Mechanisms and Their Applications': 'amma',
#  'International Workshop on Activity Monitoring by Multiple Distributed Sensing (AMMDS)': 'ammds',
#  'International Workshop on Activity Monitoring by Multiple Distributed Sensing': 'ammds',
#  'Advances in Model-Based Software Testing (A-MOST)': 'amost',
#  'Advances in Model-Based Software Testing': 'amost',
#  'International Workshop on Applied Measurements for Power Systems (AMPS)': 'amps',
#  'International Workshop on Applied Measurements for Power Systems': 'amps',
#  'Adaptive Multimedia Retrieval (AMR)': 'amr',
#  'Adaptive Multimedia Retrieval': 'amr',
#  'Autonome Mobile Systeme (AMS)': 'ams',
#  'Autonome Mobile Systeme': 'ams',
#  'Workshop on Additive Manufacturing (3D Printing) Security (AMSec)': 'amsec',
#  'Workshop on Additive Manufacturing  Security': 'amsec',
#  'AMS Meetings and Conferences': 'amsmeet',
#  'Amsterdam Colloquium': 'amsterdam',
#  'Active Media Technology (AMT)': 'amt',
#  'Active Media Technology': 'amt',
#  'Conference of the Association for Machine Translation in the Americas (AMTA)': 'amta',
#  'Conference of the Association for Machine Translation in the Americas': 'amta',
#  'Alberto Mendelzon International Workshop on Foundations of Data Management (AMW)': 'amw',
#  'Alberto Mendelzon International Workshop on Foundations of Data Management': 'amw',
#  'Workshop on Analytic Algorithmics and Combinatorics (ANALCO)': 'analco',
#  'Workshop on Analytic Algorithmics and Combinatorics': 'analco',
#  'International Conference on Algebraic and Numeric Biology (ANB)': 'anb',
#  'International Conference on Algebraic and Numeric Biology': 'anb',
#  'Symposium on Architectures for Networking and Communications Systems (ANCS)': 'ancs',
#  'Symposium on Architectures for Networking and Communications Systems': 'ancs',
#  'Workshop on Analytics for Noisy Unstructured Text Data (AND)': 'and',
#  'Workshop on Analytics for Noisy Unstructured Text Data': 'and',
#  'International Conference on Animal-Computer Interaction (ACI)': 'animalci',
#  'International Conference on Animal-Computer Interaction': 'animalci',
#  'International Workshop on Next Generation Computer Animation Techniques (AniNex)': 'aninex',
#  'International Workshop on Next Generation Computer Animation Techniques': 'aninex',
#  'Applied Natural Language Processing Conference (ANLP)': 'anlp',
#  'Applied Natural Language Processing Conference': 'anlp',
#  'Artificial Neural Networks (ANN)': 'ann',
#  'Artificial Neural Networks': 'ann',
#  'Xonference on Analysis of Neural Network Applications (ANNA)': 'anna',
#  'Xonference on Analysis of Neural Network Applications': 'anna',
#  'Artificial Neural Networks and Expert Systems (ANNES)': 'annes',
#  'Artificial Neural Networks and Expert Systems': 'annes',
#  'Conference on Artificial Neural Networks in Medicine and Biology (ANNIMAB)': 'annimab',
#  'Conference on Artificial Neural Networks in Medicine and Biology': 'annimab',
#  'IAPR International Workshop on Artificial Neural Networks in Pattern Recognition (ANNPR)': 'annpr',
#  'IAPR International Workshop on Artificial Neural Networks in Pattern Recognition': 'annpr',
#  'Artificial Neural Networks and Intelligent Information Processing (ANNIIP)': 'anns',
#  'Artificial Neural Networks and Intelligent Information Processing': 'anns',
#  'Annual Modeling and Simulation Conference (ANNSIM)': 'annsim',
#  'Annual Modeling and Simulation Conference': 'annsim',
#  'Applied Networking Research Workshop (ANRW)': 'anrw',
#  'Applied Networking Research Workshop': 'anrw',
#  'Annual Simulation Symposium (ANSS)': 'anss',
#  'Annual Simulation Symposium': 'anss',
#  'International Conference on Ambient Systems, Networks and Technologies (ANT)': 'ant',
#  'International Conference on Ambient Systems, Networks and Technologies': 'ant',
#  'International Conference on Computer Science Protecting Human Society Against Epidemics (ANTICOVID)': 'anticovid',
#  'International Conference on Computer Science Protecting Human Society Against Epidemics': 'anticovid',
#  'Algorithmic Number Theory Symposium (ANTS)': 'ants',
#  'Algorithmic Number Theory Symposium': 'ants',
#  'International Conference on Swarm Intelligence (ANTS)': 'antsw',
#  'International Conference on Swarm Intelligence': 'antsw',
#  'Australian and New Zealand Control Conference (ANZCC)': 'anzcc',
#  'Australian and New Zealand Control Conference': 'anzcc',
#  'Australian New Zealand Conference on Intelligent Information Systems (ANZIIS)': 'anziis',
#  'Australian New Zealand Conference on Intelligent Information Systems': 'anziis',
#  'International Workshop on Advanced Modularization Techniques (AOAsia)': 'aoasia',
#  'International Workshop on Advanced Modularization Techniques': 'aoasia',
#  'International Conference on Probabilistic, Combinatorial and Asymptotic Methods for the Analysis of Algorithms (AofA)': 'aofa',
#  'International Conference on Probabilistic, Combinatorial and Asymptotic Methods for the Analysis of Algorithms': 'aofa',
#  'Agent-Oriented Information Systems Workshop (AOIS)': 'aois',
#  'Agent-Oriented Information Systems Workshop': 'aois',
#  'Workshop on Aspect-Oriented Modeling (AOM)': 'aom',
#  'Workshop on Aspect-Oriented Modeling': 'aom',
#  'International Conference on Modularity (MODULARITY)': 'aosd',
#  'International Conference on Modularity': 'aosd',
#  'International Workshop on Agent-Oriented Software Engineering (AOSE)': 'aose',
#  'International Workshop on Agent-Oriented Software Engineering': 'aose',
#  'Agents and Peer-to-Peer Computing (AP2PC)': 'ap2pc',
#  'Agents and Peer-to-Peer Computing': 'ap2pc',
#  'International Conference on Advances in P2P Systems (AP2PS)': 'ap2ps',
#  'International Conference on Advances in P2P Systems': 'ap2ps',
#  'Technology, Mind, and Society Conference (APAScience)': 'apascience',
#  'Technology, Mind, and Society Conference': 'apascience',
#  'Asia-Pacific Bioinformatics Conference (APBC)': 'apbc',
#  'Asia-Pacific Bioinformatics Conference': 'apbc',
#  'Asia Pacific Business Process Management (AP-BPM)': 'apbpm',
#  'Asia Pacific Business Process Management': 'apbpm',
#  'Essays on Algebraic Process Calculi (APC 25)': 'apc25',
#  'Essays on Algebraic Process Calculi': 'apc25',
#  'Asia-Pacific Conference on Communications (APCC)': 'apcc',
#  'Asia-Pacific Conference on Communications': 'apcc',
#  'Asia Pacific Conference on Circuits and Systems (APCCAS)': 'apccas',
#  'Asia Pacific Conference on Circuits and Systems': 'apccas',
#  'Asia-Pacific Conference on Conceptual Modelling (APCCM)': 'apccm',
#  'Asia-Pacific Conference on Conceptual Modelling': 'apccm',
#  'Asia-Pacific Computer and Human Interaction (APCHI)': 'apchi',
#  'Asia-Pacific Computer and Human Interaction': 'apchi',
#  'International Conference on Research in Industrial and Systems Engineering (APCoRISE)': 'apcorise',
#  'International Conference on Research in Industrial and Systems Engineering': 'apcorise',
#  'Asia-Pacific Computer Systems Architecture Conference (ACSAC)': 'aPcsac',
#  'Asia-Pacific Computer Systems Architecture Conference': 'aPcsac',
#  'Advances / Applications in Parallel and Distributed Computing (APDC)': 'apdc',
#  'Advances / Applications in Parallel and Distributed Computing': 'apdc',
#  'Annual Privacy Forum (APF)': 'apf',
#  'Annual Privacy Forum': 'apf',
#  'ACM Symposium on Applied Perception (SAP)': 'apgv',
#  'ACM Symposium on Applied Perception': 'apgv',
#  "Conférence Nationale sur les Applications Pratiques de l'Intelligence Artificielle (APIA)": 'apia',
#  "Conférence Nationale sur les Applications Pratiques de l'Intelligence Artificielle": 'apia',
#  'Asia Pacific Information Technology Conference (APIT)': 'apit',
#  'Asia Pacific Information Technology Conference': 'apit',
#  'International Conference on Array Processing Languages (APL)': 'apl',
#  'International Conference on Array Processing Languages': 'apl',
#  'Asian Symposium on Programming Languages and Systems (APLAS)': 'aplas',
#  'Asian Symposium on Programming Languages and Systems': 'aplas',
#  'Asia Pacific Workshop on Mixed and Augmented Reality (APMAR)': 'apmar',
#  'Asia Pacific Workshop on Mixed and Augmented Reality': 'apmar',
#  'Applications and Theory of Petri Nets and Concurrency (Petri Nets)': 'apn',
#  'Applications and Theory of Petri Nets and Concurrency': 'apn',
#  'Asia-Pacific Workshop on Networking (APNet)': 'apnet',
#  'Asia-Pacific Workshop on Networking': 'apnet',
#  'Asia-Pacific Network Operations and Management Symposium (APNOMS)': 'apnoms',
#  'Asia-Pacific Network Operations and Management Symposium': 'apnoms',
#  'SIAM Symposium on Algorithmic Principles of Computer Systems (APOCS)': 'apocs',
#  'SIAM Symposium on Algorithmic Principles of Computer Systems': 'apocs',
#  'International Workshop on Scrutinizing Agile Practices or Shoot-Out at the Agile Corral (APOS)': 'apos',
#  'International Workshop on Scrutinizing Agile Practices or Shoot-Out at the Agile Corral': 'apos',
#  'Applied Informatics (AI)': 'appinf',
#  'Applied Informatics': 'appinf',
#  'Applications of Intelligent Systems (APPIS)': 'appis',
#  'Applications of Intelligent Systems': 'appis',
#  'Applications in Electronics Pervading Industry, Environment and Society (ApplePies)': 'applepies',
#  'Applications in Electronics Pervading Industry, Environment and Society': 'applepies',
#  'Workshop on Advanced Tools, Programming Languages, and Platforms for Implementing and Evaluating Algorithms for Distributed Systems (ApPLIED)': 'applied',
#  'Workshop on Advanced Tools, Programming Languages, and Platforms for Implementing and Evaluating Algorithms for Distributed Systems': 'applied',
#  'International Workshop on Approximation, Randomization, and Combinatorial Optimization. Algorithms and Techniques (APPROX)': 'approx',
#  'International Workshop on Approximation, Randomization, and Combinatorial Optimization. Algorithms and Techniques': 'approx',
#  'Advanced Parallel Programming Technologies (APPT)': 'appt',
#  'Advanced Parallel Programming Technologies': 'appt',
#  'Asia Pacific Requirements Engineering Symposium (APRES)': 'apres',
#  'Asia Pacific Requirements Engineering Symposium': 'apres',
#  'Asia-Pacific Services Computing Conference (APSCC)': 'apscc',
#  'Asia-Pacific Services Computing Conference': 'apscc',
#  'Asia-Pacific Software Engineering Conference (APSEC)': 'apsec',
#  'Asia-Pacific Software Engineering Conference': 'apsec',
#  'Asia-Pacific Signal and Information Processing Association Annual Summit and Conference (APSIPA)': 'apsipa',
#  'Asia-Pacific Signal and Information Processing Association Annual Summit and Conference': 'apsipa',
#  'Asia-Pacific Symposium on Information and Telecommunication Technologies (APSITT)': 'apsitt',
#  'Asia-Pacific Symposium on Information and Telecommunication Technologies': 'apsitt',
#  'Asia Pacific Workshop on Systems (APSys)': 'apsys',
#  'Asia Pacific Workshop on Systems': 'apsys',
#  'Asia-Pacific Symposium on Visualisation (APVIS)': 'apvis',
#  'Asia-Pacific Symposium on Visualisation': 'apvis',
#  ...}

# %%
from sentence_transformers import SentenceTransformer

# 1. Load a pretrained Sentence Transformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# The sentences to encode
sentences = list(unique_confs.keys())

# 2. Calculate embeddings by calling model.encode()
embeddings = model.encode(sentences)
print(embeddings.shape)
# [3, 384]

vector_size = embeddings.shape[1]

# # 3. Calculate the embedding similarities
# similarities = model.similarity(embeddings, embeddings)
# print(similarities)
# # tensor([[1.0000, 0.6660, 0.1046],
# #         [0.6660, 1.0000, 0.1411],
# #         [0.1046, 0.1411, 1.0000]])
# Out:
# (13554, 384)

# %%
import faiss                   # make faiss available
index = faiss.IndexFlatL2(vector_size)   # build the index
print(index.is_trained)
# Out:
# True

# %%
index.add(embeddings)                  # add vectors to the index
print(index.ntotal)
# Out:
# 13554

# %% [markdown]
# # Save index

# %%
to_save = dict()
to_save["sentences"] = sentences
to_save["index"] = index
to_save["confs"] = unique_confs
to_save["idsconfs"] = ids_confs
import pickle
with open('DBLP.pickle', 'wb') as handle:
    pickle.dump(to_save, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Test Index

# %%
sentence = "International Semantic Web Conference"
sentence = "5th International Workshop on Scientific Knowledge: Representation, Discovery, and Assessment"
embedding = model.encode([sentence])

# %%
D, I = index.search(embedding, k=3)

# %%
D
# Out:
# array([[0.08745116, 0.7501303 , 0.7509186 ]], dtype=float32)

# %%
for i in I[0]:
    print(sentences[i])
# Out:
# International Workshop on Scientific Knowledge: Representation, Discovery, and Assessment (Sci-K)
# International Conference on Discovery Science (DS)
# International Workshop on Natural Scientific Language Processing and Research Knowledge Graphs (NSLP)

# %%
i
# Out:
# array([5955, 2172, 2869])
